# %% [markdown]
# - 콜백은 훈련, 평가 또는 추론 중에 Keras 모델의 동작을 사용자 정의할 수 있는 강력한 도구입니다.
# - TensorBoard로 훈련 진행 상황과 결과를 시각화하기 위한 tf.keras.callbacks.
# - TensorBoard 또는 훈련 도중 모델을 주기적으로 저장하는 tf.keras.callbacks.ModelCheckpoint 등이 여기에 포함
#
# https://www.tensorflow.org/guide/keras/custom_callback?hl=ko
