# %% [markdown]
# ## 네이버 블로그 검색 API( 예제)

# %%
import os
import sys
import urllib.request
client_id = "dvixR84y0OQtFuhySWQZ"
client_secret = "QLTu_PrCVt"
encText = urllib.parse.quote(input("검색할 단어"))
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색할 단어바보
# {
# "lastBuildDate": "Sat, 12 Feb 2022 10:08:15 +0900",
# "total": 4209641,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "나는 엄마가 되었다!! <b>바보</b>같은 사나이이다!!",
# "link": "https:\/\/blog.naver.com\/dongsn1004?Redirect=Log&logNo=222640063715",
# "description": "해이리 아트벨리에서 아내를 위로하여 주고 서울로~~ 사람들은 나를 <b>바보</b> 같은 사나이라고한다. &quot;<b>바보</b>&quot; 맞다. 특히 돈 나눌때 나는 상상도 못할정도로 <b>바보</b>같다고한다. 심지어는 병신이라고한다. 그러나 여기에... ",
# "bloggername": "dongsn1004님의블로그",
# "bloggerlink": "https://blog.naver.com/dongsn1004",
# "postdate": "20220206"
#
# },
# {
# "title": "내가 호구(?)인 이유: <b>바보</b>처럼 살아요..",
# "link": "https:\/\/blog.naver.com\/hyunjin_seo?Redirect=Log&logNo=222575118782",
# "description": "맞거나, <b>바보</b>같단 소리 들은 적도 꽤 많네요. 블로그로 인스타 디엠으로 오는 수많은 메시지들. 믿기... 너무 <b>바보</b>같이 순진하다며 약간 <b>바보</b>같이 취급당할 때도 있어요. 매운맛을 보여주까?진짜!!! 생각해봤어요.... ",
# "bloggername": "아나운서 서현진의 블로그예요",
# "bloggerlink": "https://blog.naver.com/hyunjin_seo",
# "postdate": "20211122"
#
# },
# {
# ...

# %% [markdown]
# ### 웹문서 검색 변형

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "dvixR84y0OQtFuhySWQZ"
client_secret = "QLTu_PrCVt"
# encText = urllib.parse.quote("빅데이터")
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1        
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색 질의: 양배추
#                                    Title  \
# 0                        양배추즙 효능 위를 편안하게
# 1                         양배추즙효능 위건강에 탁월
# 2                    양배추환 효능 자세히 알고 관리해요
# 3                        양배추즙 효능 끌어올리는 법
# 4                         양배추즙 피부 위한 선택!
# ..                                   ...
# 995        영어가 싫어서 가슴이 아프고.. 그래서 양배추를 썬다
# 996          양배추환 간편하게 챙겨 먹을 수 있어서 딱 좋아!
# 997                쉽고 간단한 한그릇 요리 '양배추덮밥'
# 998               다이어트 양배추 샐러드 만들기~양배추요리
# 999  간단한 계란 양배추 샌드위치만들기 추억의 맛 길거리토스트...
#
#                                                   Link  \
# 0    https://blog.naver.com/kyemma?Redirect=Log&log...
# 1    https://blog.naver.com/city419?Redirect=Log&lo...
# 2    https://blog.naver.com/venus7676?Redirect=Log&...
# 3    https://blog.naver.com/lucidp?Redirect=Log&log...
# 4    https://blog.naver.com/c0712gywjd?Redirect=Log...
# ..                                                 ...
# 995  https://blog.naver.com/imisod?Redirect=Log&log...
# ...

# %% [markdown]
# ## 네이버 영화 검색 기본

# %%
import os
import sys
import urllib.request
client_id = "dvixR84y0OQtFuhySWQZ"
client_secret = "QLTu_PrCVt"
encText = urllib.parse.quote("마법")
url = "https://openapi.naver.com/v1/search/movie?query=" + encText # json 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %% [markdown]
# ### 네이버 영화 검색 변형

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = ""
client_secret = ""
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000

movie_df = pd.DataFrame(columns=('제목','링크','감독','배우','유저평점'))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/movie?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index)
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, "", items[item_index]['title'])
            link = items[item_index]['link']
            director = re.sub(remove_tag, '', items[item_index]['director'])
            actor = re.sub(remove_tag,'',items[item_index]['actor'])
            userRating = items[item_index]['userRating']
            movie_df.loc[idx] = [title, link, director, actor, userRating]
            idx += 1        
    else:        
        print("Error Code:" + rescode)
movie_df
# Out:
# 검색 질의: 조폭
#                    제목                                                 링크  \
# 0              어쩌다 조폭  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 1       청순한 그녀와 조폭 남친  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 2     옆집 조폭마누라는 G컵 거유  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 3             조폭의 법칙2  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 4              조폭의 법칙  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# ..                ...                                                ...
# 95           조폭 마누라 3  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 96  조폭 마누라 2 - 돌아온 전설  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 97                고쿠센  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 98             조폭 마누라  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 99             조폭의 여자  https://movie.naver.com/movie/bi/mi/basic.nhn?...
#
#            감독                                       배우  유저평점
# ...

# %% [markdown]
# ## 네이버 이미지 검색 기본

# %%
import os
import sys
import urllib.request

client_id = "dvixR84y0OQtFuhySWQZ"
client_secret = "QLTu_PrCVt"
encText = urllib.parse.quote("교통사고")
url = "https://openapi.naver.com/v1/search/image?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Sat, 12 Feb 2022 16:32:25 +0900",
# "total": 526053,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "-극혐- BMW 530I 사고사진 | 보배드림 교통사고/사건/블랙박스",
# "link": "https://file1.bobaedream.co.kr/multi_image/accident/2014/09/11/16/AhY5411488fd8445.jpg",
# "thumbnail": "https://search.pstatic.net/sunny/?src=https://file1.bobaedream.co.kr/multi_image/accident/2014/09/11/16/AhY5411488fd8445.jpg&type=b150",
# "sizeheight": "496",
# "sizewidth": "670"
#
# },
# {
# "title": "서울 종로5가서 차량 4대 교통사고…2명 경상",
# "link": "http://imgnews.naver.net/image/056/2021/08/14/0011101490_001_20210814221705934.jpg",
# "thumbnail": "https://search.pstatic.net/common/?src=http://imgnews.naver.net/image/056/2021/08/14/0011101490_001_20210814221705934.jpg&type=b150",
# "sizeheight": "360",
# "sizewidth": "640"
#
# },
# {
# "title": "여캠이 갑자기 '휴방 공지' 했는데 아무도 욕 못하게 만든 처참한 '교통사고' 사진",
# ...

# %% [markdown]
# ### 이미지 검색 변형

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = ""
client_secret = ""
query = urllib.parse.quote(input("검색 질의: "))

idx = 0
display = 100
start = 1
end = 1000
size = 'large'

image_df = pd.DataFrame(columns=('제목','링크','썸네일'))
for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/image?query=" + query \
    + "&display=" + str(display) \
    + "&start=" + str(start_index) \
    + "&filter=" +str(size)
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            title = items[item_index]['title']
            link = items[item_index]['link']
            thumbnail = items[item_index]['thumbnail']
            image_df.loc[idx] = [title, link, thumbnail]
            idx += 1        
    else:        
        print("Error Code:" + rescode)
image_df
# Out:
# 검색 질의: tkrh
#                                                     제목  \
# 0    YouTube: justanordinarygirl10  | girl, beautif...
# 1    Rijeka, snimljeno na zaobilaznici : croatia r/...
# 2                             도로교통공단, 상습정체·사고다발 교차로 개선
# 3             초등생 탄 관광버스 추돌…20명 부상 | 보배드림 교통사고/사건/블랙박스
# 4              부산서 버스가 인도로 돌진하는 사고 | 보배드림 교통사고/사건/블랙박스
# ..                                                 ...
# 130                   안성 종이상자 공장서 폭발… 소방관 1명 사망·부상 10명
# 131  정품 AXE MKJ 공식총판 숄더백 크로스백 미니백 핸드백 핸드폰가방 여성가방 선물...
# 132                zhsla ghkwkdvna fjscldgktlskqhkdy!
# 133                           부산시 '사람중심·안전우선' 마을버스 만든다
# 134                      부산시, 마을버스 안전점검…33개 업체 288대 대상
#
#                                                     링크  \
# 0    https://data.whicdn.com/images/328709638/large...
# 1    https://preview.redd.it/vxn1bom1fg041.jpg?auto...
# 2    http://imgnews.naver.net/image/5297/2016/01/08...
# 3    https://file1.bobaedream.co.kr/accident/accide...
# ...

# %% [markdown]
# ## 날씨 API

# %%
import requests
import json 

api_key = "855d135707a32b014b2ac164e84aeb33"
city_list=['Seoul','Tokyo','New York,US']
for city in city_list:
    city_name = city
    url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + api_key + "&q=" + city_name +"&units=metric"
    response = requests.get(url).text
    print(response)
# Out:
# {"coord":{"lon":126.9778,"lat":37.5683},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":2.69,"feels_like":2.69,"temp_min":-0.77,"temp_max":2.69,"pressure":1021,"humidity":67,"sea_level":1021,"grnd_level":1014},"visibility":10000,"wind":{"speed":1.22,"deg":131,"gust":1.91},"clouds":{"all":100},"dt":1644800401,"sys":{"type":1,"id":8093,"country":"KR","sunrise":1644791007,"sunset":1644829760},"timezone":32400,"id":1835848,"name":"Seoul","cod":200}
# {"coord":{"lon":139.6917,"lat":35.6895},"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04d"}],"base":"stations","main":{"temp":4.91,"feels_like":0.15,"temp_min":2.51,"temp_max":6.4,"pressure":1018,"humidity":72},"visibility":10000,"wind":{"speed":7.72,"deg":10},"clouds":{"all":75},"dt":1644801010,"sys":{"type":2,"id":2038398,"country":"JP","sunrise":1644787799,"sunset":1644826866},"timezone":32400,"id":1850144,"name":"Tokyo","cod":200}
# ...

# %%
import requests
import json 

api_key = "855d135707a32b014b2ac164e84aeb33"
city_list=['Seoul','Tokyo','New York,US']
for city in city_list:
    city_name = city
    url = "http://api.openweathermap.org/data/2.5/weather?" + "appid=" + api_key + "&q=" + city_name +"&units=metric"
    response = requests.get(url)
    weather_data = response.json()
    temp1 = weather_data['weather']  # description - 메인 날씨
    temp2 = weather_data['main'] # temp_min, temp_max, pressure, humidity
    temp3 = weather_data['wind'] # speed
#   display(temp1,temp2,temp3)
    description = temp1[0]['description']
    temp_min = temp2['temp_min']
    temp_max = temp2['temp_max']
    humidity = temp2['humidity']
    pressure = temp2['pressure']
    speed = temp3['speed']
    print(f'+ 도시 = {city_name}')
    print(f'| 날씨 = {description}')
    print(f'| 최저 기온 = {temp_min}')
    print(f'| 최고 기온 = {temp_max}')
    print(f'| 습도 = {humidity}')
    print(f'| 기압 = {pressure}')
    print(f'| 풍속 = {speed}')
    print()
# Out:
# + 도시 = Seoul
# | 날씨 = overcast clouds
# | 최저 기온 = -0.77
# | 최고 기온 = 2.69
# | 습도 = 67
# | 기압 = 1021
# | 풍속 = 1.22
#
# + 도시 = Tokyo
# | 날씨 = broken clouds
# | 최저 기온 = 2.51
# | 최고 기온 = 5.99
# | 습도 = 74
# | 기압 = 1018
# | 풍속 = 7.72
#
# + 도시 = New York,US
# | 날씨 = overcast clouds
# | 최저 기온 = -3.65
# | 최고 기온 = -0.84
# | 습도 = 67
# | 기압 = 1018
# | 풍속 = 6.17

# %%
# !pip install xmltodict

# %% [markdown]
# ## 팀 api 기본

# %%
import json
import requests

ServiceKey = 'p6rQtYpFx5ZivDokXiWeZEPT1qg7CGrnWM9XP9rPcOy45BUhyI3RM9OoXCo3CWSAH31Va67TZGHaOOFWN/I7Cg==' 
#인증키 - (본인 URL Encode 사용)
searchYear = [2017,2018,2019,2020]
#연도코드 - ( 가능한 년도 옵션이 2017 - 2020 까지만 존재)
siDo = [11,26,27,28,29,30]
#시도코드 - ex(서울 - 11, 부산 - 26, 대구 - 27, 인천 - 28, 광주 - 29, 대전 - 30)
# siDo[0] - 서울
guGun = [680,740,305,500,440,410]
# 시군구코드 ( 시도코드와 시군구코드는 서로 연관이 있어야함 서울시도코드에서 부산구군코드 사용불가능 검색 결과 없음)
# 서울 {강남구 680, 강동구 740, 강북구 305, 강서구 500}
numOfRows = 100 
# 검색건수
pageNo = 1
# 페이지 번호 ( 전체 검색 검수를 확인해 보며 페이지 번호 선택)

url = 'http://apis.data.go.kr/B552061/frequentzoneLg/getRestFrequentzoneLg'
params ={'serviceKey' : ServiceKey, 'searchYearCd' : searchYear[0], 'siDo' : siDo[0], 'guGun' : guGun[0], 'type' : 'xml', 'numOfRows' : numOfRows, 'pageNo' : pageNo }
response = requests.get(url, params=params)
print(response.text)
# Out:
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <afos_fid>6467461</afos_fid>
#                 <afos_id>2018074</afos_id>
#                 <bjd_cd>11680108</bjd_cd>
#                 <spot_cd>11680001</spot_cd>
#                 <sido_sgg_nm>서울특별시 강남구1</sido_sgg_nm>
#                 <spot_nm>서울특별시 강남구 논현동(역삼역 인근)</spot_nm>
#                 <occrrnc_cnt>57</occrrnc_cnt>
#                 <caslt_cnt>69</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>17</se_dnv_cnt>
#                 <sl_dnv_cnt>44</sl_dnv_cnt>
#                 <wnd_dnv_cnt>8</wnd_dnv_cnt>
# ...

# %%
import json
import requests

ServiceKey = 'p6rQtYpFx5ZivDokXiWeZEPT1qg7CGrnWM9XP9rPcOy45BUhyI3RM9OoXCo3CWSAH31Va67TZGHaOOFWN/I7Cg==' 
#인증키 - (본인 URL Encode 사용)
searchYear = [2017,2018,2019,2020]
#연도코드 - ( 가능한 년도 옵션이 2017 - 2020 까지만 존재)
siDo = [11,26,27,28,29,30]
#시도코드 - ex(서울 - 11, 부산 - 26, 대구 - 27, 인천 - 28, 광주 - 29, 대전 - 30)
# siDo[0] - 서울
guGun = [680,740,305,500,440,410]
# 시군구코드 ( 시도코드와 시군구코드는 서로 연관이 있어야함 서울시도코드에서 부산구군코드 사용불가능 검색 결과 없음)
# 서울 {강남구 680, 강동구 740, 강북구 305, 강서구 500}
numOfRows = 100 
# 검색건수
pageNo = 1
# 페이지 번호 ( 전체 검색 검수를 확인해 보며 페이지 번호 선택)

url = 'http://apis.data.go.kr/B552061/frequentzoneLg/getRestFrequentzoneLg'
params ={'serviceKey' : ServiceKey, 'searchYearCd' : searchYear[0], 'siDo' : siDo[0], 'guGun' : guGun[0], 'type' : 'json', 'numOfRows' : numOfRows, 'pageNo' : pageNo }
response = requests.get(url, params=params)
dictionary = response.json()
dictionary
# Out:
# {'resultCode': '00',
#  'resultMsg': 'NORMAL_CODE',
#  'items': {'item': [{'afos_fid': 6467461,
#     'afos_id': '2018074',
#     'bjd_cd': '11680108',
#     'spot_cd': '11680001',
#     'sido_sgg_nm': '서울특별시 강남구1',
#     'spot_nm': '서울특별시 강남구 논현동(역삼역 인근)',
#     'occrrnc_cnt': 57,
#     'caslt_cnt': 69,
#     'dth_dnv_cnt': 0,
#     'se_dnv_cnt': 17,
#     'sl_dnv_cnt': 44,
#     'wnd_dnv_cnt': 8,
# ...

# %% [markdown]
# ## 팀 API 예제

# %%
# https://www.data.go.kr/data/15057467/openapi.do - api 신청
import json
import requests
import pandas as pd
import numpy as np
ServiceKey = 'p6rQtYpFx5ZivDokXiWeZEPT1qg7CGrnWM9XP9rPcOy45BUhyI3RM9OoXCo3CWSAH31Va67TZGHaOOFWN/I7Cg==' 
#인증키 - (본인 URL Encode 사용)
searchYear = [2017,2018,2019,2020]
#연도코드 - ( 가능한 년도 옵션이 2017 - 2020 까지만 존재)
siDo = [11,26,27,28,29,30]
#시도코드 - ex(서울 - 11, 부산 - 26, 대구 - 27, 인천 - 28, 광주 - 29, 대전 - 30)
# siDo[0] - 서울
guGun = [680,740,305,500,440,410]
# 시군구코드 ( 시도코드와 시군구코드는 서로 연관이 있어야함 서울시도코드에서 부산구군코드 사용불가능 검색 결과 없음)
# 서울 {강남구 680, 강동구 740, 강북구 305, 강서구 500}
numOfRows = 100 
# 검색건수
pageNo = 1
# 페이지 번호 ( 전체 검색 검수를 확인해 보며 페이지 번호 선택)

car_df = pd.DataFrame(columns=('다발지역지점','사고발생건수','사상자수','경도','위도'))

url = 'http://apis.data.go.kr/B552061/frequentzoneLg/getRestFrequentzoneLg'
params ={'serviceKey' : ServiceKey, 'searchYearCd' : searchYear[0], 'siDo' : siDo[0], 'guGun' : guGun[0], 'type' : 'json', 'numOfRows' : numOfRows, 'pageNo' : pageNo }
response = requests.get(url, params=params)
dictionary = response.json()
count = dictionary['totalCount']
for i in np.arange(count):
    temp = dictionary['items']['item'][i]
    spot_nm = temp['spot_nm']
    occrrnc_cnt = temp['occrrnc_cnt']
    caslt_cnt = temp['caslt_cnt']
    lo_crd = temp['lo_crd']
    la_crd = temp['la_crd']
    car_df.loc[i] = [spot_nm,occrrnc_cnt,caslt_cnt,lo_crd,la_crd]
    
car_df
# Out:
#                          다발지역지점 사고발생건수 사상자수                경도               위도
# 0         서울특별시 강남구 논현동(역삼역 인근)     57   69  127.036931109384  37.500825074718
# 1     서울특별시 강남구 논현동(교보타워사거리 인근)     49   74  127.024486357461  37.504521276637
# 2  서울특별시 강남구 논현동(CHA여성의학연구소 인근)     44   69  127.033889484413  37.507329308102

# %% [markdown]
# ## 활용사례
# url : https://scienceon.kisti.re.kr/srch/selectPORSrchReport.do?cn=TRKO201800004574
#
# - 빅데이터 기술을 활용하여 수리적 리스크통계의 접근하는 방식이 아닌 사과결과와 사고 요인간의 연관성을 기계학습을 통해 정량화 하여 사고 특성에 따른 사고 다발지역 선정과 분류 작업을 통해 위험 지도 제작을 함.
#
# 활용계획
#
# 1. 기술적 효과
#
# - 도로 환경 및 상황적 요인이 교통사고 발생에 미치는 영향을 분석하는 기반제공
# - 자율 주행 등 미래 교통 시스템 안전관리 기반 기술 마련
#
# 2. 경제적 효과
# - 빅데이터의 지속적인 성장에 따른 교통 분야의 시스템 매출 증대
# - 선진국 수준의 교통사고 분석 기술 개발
#
# 3. 사회적 효과
# - 보다 안전한 도로교통 시스템을 통한 국민체감적 안전확보
# - 선진형 도로 교통 안전관리 문화 수립 기반 마련
# - 테이터에 기반한 효율적인 사고예방과 위험경감 조치 방안 제공

# %%
key = RJCLlpv%2BeRnJLSW7OleNUNZG7x8DKqpRj8c6ynFG1gkAD6UyEhHMBw%2BUVlWJ8pnK
url =

# %%
import PIL.Image as pilimg

# %%
#key = 'RJCLlpv%2BeRnJLSW7OleNUNZG7x8DKqpRj8c6ynFG1gkAD6UyEhHMBw%2BUVlWJ8pnK'
#searchYearCd = '2021056'
#siDo = '11'
#guGun = '680'

url = 'http://taas.koroad.or.kr/data/wms/frequentzone/lg?\
authKey=RJCLlpv%2BeRnJLSW7OleNUNZG7x8DKqpRj8c6ynFG1gkAD6UyEhHMBw%2BUVlWJ8pnK\
&layers=frelg&format=image/png&transparent=TRUE&service=WMS&version=1.1.1&request=GetMap&bbox=126.966,37.484,127.103,37.623&width=512&height=469&srs=EPSG:4326&searchYearCd=2017&siDo=11&guGun=200'


data = requests.get(url)
data
# Out:
# <Response [200]>

# %%
import json
import requests

ServiceKey = 'RJCLlpv%2BeRnJLSW7OleNUNZG7x8DKqpRj8c6ynFG1gkAD6UyEhHMBw%2BUVlWJ8pnK' 
#인증키 - (본인 URL Encode 사용)
searchYear = [2017,2018,2019,2020]
#연도코드 - ( 가능한 년도 옵션이 2017 - 2020 까지만 존재)
siDo = [11,26,27,28,29,30]
#시도코드 - ex(서울 - 11, 부산 - 26, 대구 - 27, 인천 - 28, 광주 - 29, 대전 - 30)
# siDo[0] - 서울
guGun = [680,740,305,500,440,410]
# 시군구코드 ( 시도코드와 시군구코드는 서로 연관이 있어야함 서울시도코드에서 부산구군코드 사용불가능 검색 결과 없음)
# 서울 {강남구 680, 강동구 740, 강북구 305, 강서구 500}
numOfRows = 100 
# 검색건수
pageNo = 1
# 페이지 번호 ( 전체 검색 검수를 확인해 보며 페이지 번호 선택)

url = 'http://taas.koroad.or.kr/data/rest/frequentzone/lg?authKey='
params ={'serviceKey' : ServiceKey, 'searchYearCd' : searchYear[0], 'siDo' : siDo[0], 'guGun' : guGun[0], 'type' : 'json', 'numOfRows' : numOfRows, 'pageNo' : pageNo }
response = requests.get(url, params=params)
dictionary = response.json()
dictionary
# Out:
# {'resultCode': '30', 'resultMsg': 'SERVICE_KEY_IS_NOT_REGISTERED_ERROR'}

# %%
from PIL import Image
import urllib
import time
from io import BytesIO

url = "https://search.pstatic.net/common/?src=http%3A%2F%2Fpost.phinf.naver.net%2FMjAxODExMTZfMjE0%2FMDAxNTQyMzU4MDY1OTE3.mke0JLFBO4jS-hJojejDruHQmJkV7b4gKs3oRfn7tdIg.1LxHXj9zP7M09hPrht0iW17TRKkmCAgV6kEjTgPtPDcg.JPEG%2FI1P4kSElZvKVehuLxO8qMBSTUkIU.jpg&type=sc960_832"

# time check
start = time.time()

# request.urlopen()
# HTTP Error 403: Forbidden 에러 때문에 하단의 소스 한 줄을 추가해주었다.
req = urllib.request.Request(url, headers = {"User-Agent" : "Mozilla/5.0"})
res = request.urlopen(req).read()

# 이미지 다운로드 시간 체크
print(time.time() - start)

res=requsets.get(url)
print(url)
# Image open
urlopen_img = Image.open(BytesIO(res))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16872/2902987283.py in <module>
#      12 # HTTP Error 403: Forbidden 에러 때문에 하단의 소스 한 줄을 추가해주었다.
#      13 req = urllib.request.Request(url, headers = {"User-Agent" : "Mozilla/5.0"})
# ---> 14 res = request.urlopen(req).read()
#      15
#      16 # 이미지 다운로드 시간 체크
#
# AttributeError: 'Request' object has no attribute 'urlopen'

# %%
import json
import requests

url = 'http://apis.data.go.kr/B552061/frequentzoneLg/getWMSFrequentzoneLg?ServiceKey=p6rQtYpFx5ZivDokXiWeZEPT1qg7CGrnWM9XP9rPcOy45BUhyI3RM9OoXCo3CWSAH31Va67TZGHaOOFWN%2FI7Cg%3D%3D\
&layers=frelg&format=image/png&transparent=TRUE&service=WMS&version=1.1.1&request=GetMap&bbox=126.966,37.484,127.103,37.623&width=512&height=469&srs=EPSG:4326&searchYearCd=2017&siDo=11&guGun=200'

response = requests.get(url)
print(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16872/1604249895.py in <module>
#       5 &layers=frelg&format=image/png&transparent=TRUE&service=WMS&version=1.1.1&request=GetMap&bbox=126.966,37.484,127.103,37.623&width=512&height=469&srs=EPSG:4326&searchYearCd=2017&siDo=11&guGun=200'
#       6
# ----> 7 res=requsets.get(url)
#       8 print(res)
#
# NameError: name 'requsets' is not defined

# %%
key = 'RJCLlpv%2BeRnJLSW7OleNUNZG7x8DKqpRj8c6ynFG1gkAD6UyEhHMBw%2BUVlWJ8pnK'
searchYearCd = '2018'
siDo = '11'
guGun = '200'
# &layers=frelg&format=image/png&transparent=TRUE&service=WMS&version=1.1.1&request=GetMap&bbox=126.966,37.484,127.103,37.623&width=512&height=469&srs=EPSG:4326&searchYearCd=2017&siDo=11&guGun=200'

url = f'http://taas.koroad.or.kr/data/wms/frequentzone/lg?\
authKey={key}\
&layers=frelg\
&format=image/png\
&transparent=TRUE\
&service=WMS\
&version=1.1.1\
&request=GetMap\
&bbox=126.966,37.484,127.103,37.623\
&width=512\
&height=469\
&srs=EPSG:4326\
&searchYearCd={searchYearCd}\
&siDo={siDo}\
&guGun={guGun}'

res = requests.get(url)
print(url)
# Out:
# http://taas.koroad.or.kr/data/wms/frequentzone/lg?authKey=RJCLlpv%2BeRnJLSW7OleNUNZG7x8DKqpRj8c6ynFG1gkAD6UyEhHMBw%2BUVlWJ8pnK&layers=frelg&format=image/png&transparent=TRUE&service=WMS&version=1.1.1&request=GetMap&bbox=126.966,37.484,127.103,37.623&width=512&height=469&srs=EPSG:4326&searchYearCd=2018&siDo=11&guGun=200
