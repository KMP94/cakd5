# %% [markdown]
# # LSTM으로 텍스트 생성하기
#
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현
#
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.

# %%
from tensorflow.keras import utils
import numpy as np

path = utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# 614400/600901 [==============================] - 0s 0us/step
# 말뭉치 크기: 600893

# %%
text[:500]
# Out:
# 'preface\n\n\nsupposing that truth is a woman--what then? is there not ground\nfor suspecting that all philosophers, in so far as they have been\ndogmatists, have failed to understand women--that the terrible\nseriousness and clumsy importunity with which they have usually paid\ntheir addresses to truth, have been unskilled and unseemly methods for\nwinning a woman? certainly she has never allowed herself to be won; and\nat present every kind of dogma stands with sad and discouraged mien--if,\nindeed, it s'

# %%
#60개 글자로 된 시퀀스를 추출
maxlen=60

#세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링
step=3

sentences=[] # 추출한 시퀀스 담을 리스트
next_chars=[]# 타킷(시퀀스 다음 글자)을 담을 리스트

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))
# Out:
# 시퀀스 개수: 200278

# %%
# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)
# Out:
# 고유한 글자: 57

# %%
# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 벡터화...

# %%
# 네트워크 구성
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.models import Sequential

model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

# %%
from tensorflow.keras.optimizers import RMSprop

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## 언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1.	지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2.	특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %% [markdown]
# 밑이 자연상수 e인 지수함수(e^x)의 그래프<br>
# https://wooono.tistory.com/214
#
# Python Numpy.log()-로그 <br>
# https://www.delftstack.com/ko/api/numpy/python-numpy-log/

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60): # 60 에포크 동안 모델 훈련
    print('에포크', epoch)
    model.fit(x, y, batch_size=128, epochs=1) # 데이터에서 한 번만 반복해서 모델 학습
    
    seed_text = text[start_index: start_index + maxlen] # 무작위로 시드 텍스트를 선택한다.
    print('--- 시드 텍스트: "' + seed_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]: # 여러 가지 샘플링 온도를 시도
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400): # 시드 텍스트에서 시작해서 400개의 글자를 생성한다.
            # 원 핫 인코딩으로 바꿈
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text): 
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 16s 7ms/step - loss: 1.9529
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense the sense and the sense and the sense the sense the sense the sense the sense and such all the sense the sense and the sense that is the sense the sense and the philosophy, which the sense the sense the sense of the sense the sense the sense the sense that the sense the sense of the sense and the sense and the sense of the sense the sense of the sense and the sense the gre
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the such a thisse to constarious the sense for the selferief that we conterration than the faither the german of the moral that it is the hes which considerd in the sense of the soul the world generation the be so taste that is like in the considence, but and the kood this the
# deait in
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forausernis, also--must chear, has ever
# yrought upon the onlighthel man which alone revelor. like firatizes. the
# dolitmen--and
# tow
# snifetersances and that makes--a stapen of tantar religious fat find makinessulises to sugficess
# to not enrad have eminds to  do tenoues and
# in have muthtychy
# in he
# how generage the dy whichical generalisy-, amon the rechclosipituthing
# to pasureine but itstont to a vell
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for ;oor ond contrivesive one very be midhing su,
# dand is hence. tro; intucie, wh
# menh bording con
# ided will
# to now ditporitions.
#
# b0kuremoblenews of and long 'en tipe
# worl, tho groy, orage., eterphy.-;
# our speiniog7egm! reegoved by amckom! the etcariim-tuse vory to love tapend a youghts oursuciselfelt and real emphatosrerms youd,.non it ad=ie; of ph old" and moktiedunaty
# buls deligro dedeet we hist
# 에포크 2
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.6087
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spiritual of the something the something the spirity of the more the something the more in the spirity of the condition of the something the can one with the man and more to be the spiritual to the concerts of the spirity of the sufferer to the sense of the more in the more the something the conduces of the something the property of the something to be the explanted the spirit of the more an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the suffered to the the best the property and conducery of the feels the dispungers of the condition of "be a must of the something religion of the more religion is a stronger the virtues to should nothing more to to be sude his present, and more the saverity of the sense of the one of the does to the predition of the more and history of the presentices of the graves to which the will to more an
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for promordity strungnf   pain--in spirity
# syjuy of
# all the progration, or many, shubtic usity of present; as trutes of the convucis.ence to called with that epeven they : mask hor onews yet us illyses to lightnors someto not findsly our pobjectly, and vaning to barkerhouser to grad different and the biring uses of how
# close lake shures of suffers always
# faith
# it is yon.merated himself beings, the
# s
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for my hoved and soul, more--human at race; juon lentlih to we great, i ford to at sulsion. it hor under by ho joy "trul
# fron the he
# doing of ruch, add (var? the a sinarwbned womatory and entaction, with
# vulloeb art reflict. once still man of
# mryw6. is man may bade.
#
# s; wise,
# practice or slieng, swade to ske-seeker once alloks"s, is how on  yhenction; id; its ainsxly alceatior--ins: with themselved
# 에포크 3
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.5227
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the interpretation to the sense of the sense of the condition of the sense and a the word to the word to the strong to the sense of the sense of the sense and the and the senses and the higher and the precertion to the individual to the commonstition to the sense of the sense of the sense of the sense of the condition of the fined to the greater to the sense of the greater the strong to the prec
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the strong to attracely as the action of the make with a soul of the finele
# in the virtued and the finer the things to every middle, and someare and according a do the entiment the dangerous to the senses and the distention to the do the present
# to the commanding of the short, and the fined to account to man and the accirioted to be the condition the tending the the existing a promacity to one m
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for i moral pregain one of himy" usual ano his from the words regarity to igntrensy
# howed, there for the reperham to miderdin. their bow,,isrectious,
# to do not bad to atteilagion in unterious posingr"
# (i causases,
# in that he are wouqpatisl; the pare to untrurdinalism they
# cale to ablet ally fort from held, eliminary of time ane obligpency how mady tenhity. mow,
# intere tichilary to he impread of ne
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foo-hed usy is indignt hasing traughtless. nombourable, more vary
# still, romage, patteray, rule, god obs. descount to breasuloved with a tes s the tretarity, this men rathing,xy kto them goed has grimind a healture
# nraitharitation foo a is to risrous the mance aten eyucly disguiced: whe dimpecles to himself, to ruch belityed ocher commandinally miss. kill man merilwsxoratic of attignaringery dure no
# 에포크 4
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4808
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the christian and the deato of the struction of the sense of the most the structing to the sense of the spirit of the sense of the structive the structing and all the superioring and powerful and the struct and the subliction of the same the spirit that the cholod of the spirit of the same any and the structing and the more all the structing to the structing the still the struct and all the spir
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the printless and things upon the excession, it is a says and contemption the power to the reason the account and all the suddenly of the succesticg, the precisely be attained and perhaps the more and the healter should be a stragally the rule of the borty that it is the tention of the succestiating of the pour of nature, it is an are the spirit, is a superiorary may and event of who has we are
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for eventheiny and but opinion of allow faith rebolite. to
# time oy the cower than as "power, way
# and kindful of the from each can a defined in
# rumsen happins ic of necessity approcisable even: a commond attent of those an assacuimate of rore, iminatible pains. thzard, so it a school they thousans of ejsy, it may thing suich precaued to decerned and divine to
# ausvouative, just
# according as   no dornk
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forthord that the worth tribarly perhaps let "epinuraatism.
#
# ro1lhjorg,
# had
# s4retess, litic
# tor races" pessivendings; and thoweolike-"scholagak povilate let his fechion me demar
# wickness and his matter of
# mil; just virtue,
# impulsion abduration a=pootumand--a, than which davilor; it is that muth, it i aptate us ubtrement finiom
# arff-enchuring futters and the love tore eterntl-way secvece
# of him upon
# 에포크 5
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4498
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present to the speciate of the disconditions of the strength and the consequence that the conscience of the stronger and artists the spirit that the constantly the speciate of the same the provides to the most the consequence of the consequence of the stronger and concerned to the contrary the strongest the strongest the greatest the conscience of the consequence that the spirit to the condi
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the science of innocence and present, and
# nothing in the taste of the destance of the structing that his way for the consideration of the scient for the conselution of the still the true and
# and does not in every that the most our fact of the reason that the self the gratitical and of the singularible and the sportration of the fact the conclusions, the predict it is for it attempt of the most t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for espects. the inconsciencted atlookive and that it in the attruatory obviotuisle yet
# revoluntes in evieded and man religions, they canemorfis. it ischasuity recandenly sharply, we regard to according
# to if it
# meals the everung of mendetionous, storr, preserve man;s the
#  a delicately, in mode sanss and schrepsical best
# the
# treater
# islenest natured and
# consciesserate; but a thinged of our abrearica
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for his "invery al; ditge and dion; that it tastee--thel uneesthine mon in necessary, is but to insigition: they arte,wnwism of sick.
# to ethfinest out oftanting
# has are
#
#   high onement. the subject "bouttoro. a
# myridipses,--as acts whan
# it has opporer, and the uva1vey,
# there faration of temponing, their ornetisefil, so nationi mosticping
# forffilme sla"k and invormened fearfuless.w-called jest
# and me
# 에포크 6
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4301
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength and be strength and the sense of the senses and self-recogning and still present to the present and all the more the self-respect of the self-restress of the self-confound and the more to the strength and self-restrained and the same the self-restress and man as a soul. in the self-religion and self-restrained and soul. all the sense of the senses and the senses of the self-restress
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a consequent and attent of menstome who restrengancy, and have all self-religion to the men and thinkers, in the morality and the sense and morality with that every great religion and inferally in the least of the morality and will as that even to the charm and recoldiness of men is a such the world as a deceived and all deception of the strength, there are for a now the supidesists of speciates
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for life aeppating only to action "who areinary vain as its strengthariches upon it to be true,
# "the spirit thirse.
#
# lok "vedantual europ" and the question whether uses a disintliess to now has to scorn and lest bad if see. es away, as pramonot
# to a higher regard and all femed, easily of man? would their averible, from existence, as the for what is spirit. meaning as a charms who
# this long was aliok
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folly, not,
# would though of
# which oits, diredhed. comparaces,
# "so
# mes: sus wher compressediaphy,
# the brasme
# later know
# his own sobitualishmenceo's
# hespromaw wanteveryne iy writs of liveless stretce, but
# could fasmes--fear, of incemetation,
# logates, at these menwardies and trebblar lames aqutisforily: if herstriat" acts of accuracter, against vepters? net pressert here-in many all scient carn hims
# 에포크 7
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4109
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sentiments of the same man and and has not be the development of the most perceive and the sentiments of the most instincts and and the most the same the same the sentiments of the sentiment and instance, and the same the most promision of the most strength and the strength and one and the most perhaps the senses of the same the sense of the most consideration of the same man and and and ins
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for man and not have not the sentiments, it is in the conditions who be say, and when a distress and
# restent one of the soul has a people varies of the world are series of the most strength, the pleasure and for instence of the fact man of
# the strength. it is a sole the free spirit without provister the weak, which the reason and belief is again, and the consequently and compart with the perhapsies
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for he neighcous, and god, as nethered. althis, the absurd
# than
# inewed and be for insbrive, and because it is non mentart blaih, determively when
# part witeness, and also and power, who enrmons, each his rore "look of the releption that sniination indens of life
# in ecternically
# yet
# man other why material, impossios more, that the restrain poifies,"--nameless became evils and were opposing to
# ammuthe
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folly wense it was traugarly odsel"?
#
#
# 22it it isthientful
# anweth: no deasongrential to
# endurable
# tason of
# eximate philosoch go,albrees, is how, not parars with it--and or is the speaple, to possess we a sod
# to goon eminfully
# promit holy,
# the
# srembfring
# mentest the
# highest certaining, to relingly upeing books, a cake--when mardegeine
# peodle each have
# .ot so and consequently aminals? with
# pe.milage f
# 에포크 8
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.3993
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength and forestic and in the strength and states and states of the strength and sense of the states of the strong and strong and in the same the free spirits--a present of the strength and the strong and the perceived and all the strong and man are the strong and all and the strong and in the consequently and in the same the strong and in the strength and will and states and states and i
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the stranges of the sense is its conceal, for all of the profound of a great and expline man, the recognically also the contempt to the discontinting and changers and so way that the happiness and was the conceal: in the deceive are not have he cannot in the do not finds the strenger to distance, who will stand of man--it will the states the problem in the prised and contempt of the bosk and say
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for and you convers friends, one santable, which we volis in man, means. the bady
# ton--against who canftince itself
# "more fathers intentionsh, living grand not coits
# of simmallicr findants of falseless of conditions of the farch of gleootic men are musiobilied for himself--has for ehother a ;evered
# world whom unthe badsulm. it is spiritifielfus or   leights among succemponal tromages are sure one wi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formers the higher german selpidingerained; shosso philosophhresive commence apely stoma, ahem-revengent of repeases he wainisal cersests if it was plagning of classing. betwet manners--is would how opservers for the natural os nature of mepistr, and we sniffick menleol, very way by a pry
# of hkadgarifere's invided to the beails mystare of his moralied
# owe, faurs alwaws no clevinise instincy ciction,
# 에포크 9
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3871
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the sense of the most sense of the spirit of the happiness and the supers in the stronger to the spirit of the spirit of the sense of the sense of the spirit of the strong the truth, and the spirit and all the strong and conscience of the spirit of the spirit of the sense of the spirit of the spirit of the experience, and and the spirit of the spirit of the spirit of the spirit of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly in the causes of them and men in some man to consideration, that was the deceded
# thinking of the tempteners of the each the thought that the existence in his problem of the self-betaken the feelings in its upon the ear the feeling of the world allow in the good and more german strong and domanis to make the same the succers of the self-begonsuclogence, the consequently the ethical that the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for moraler allow standard the sustilarry miragiems propen with formed of bed people follow, stear and frot precised and does not our charm to too some to seem a schopenhauer eke science, impuration. but seem but mrambing
# think into essensed by him
# an instinction of gone of collectation is exictionary begrge
# estiments and to with a philosop oracidial our spiritobly seararry
# more ethy, and in someala
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fores--which isnay-of fell-wan
# elefued our "prevents, ow sinh, hardsqupced by lake, the de thinss take-self vossation of other
# corruct, uneforfueteway to the pvecially anythitapy!
# as cafushing, the cormouratrer, will werrs--there even .phelined charmare about of
# successible into under ultremary bargeriaf, or do fandrarion,buncisies of
# anrambit" this extent andly in them te"med of being tendancesible
# 에포크 10
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3776
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the sense the contrary and supposing the conscience of the same the conduct and all the spirit of the cause of the germans of the profound to the profound and the same the conscience of the same more period the most passion of the contrasy of the same the sense the most become for the most sense and such as the period the profound and suffering and the spirit and strange of the same the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the possible. all of the fact existence, which exeeting voliag pain of the passions of the destrest false the intellectually be the taste of above the world in the plesses the nature as the complesse of mankind of the very say, and the short of mankind the fact and have a superiority and period culture of the same thinking has the experience and called that well which the progrest has been self-
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for him we see sjunt: something att and periods the lateringuishary the
# bring ascedbtion and
# penisancy of woman"
# with yet hence of the espected there aristory and resultufuting able of the senses much so believe net, who the stape, its yes no desidence of namele ethly, lapt too grow the mortoc. and securely name think of caubeive words,
# who emotion by "will his facts forth. the
# greeksism reference h
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for misloniasming is time thea-eaworn, and nature is graffenoly, and 'thistwisedment of order
# anotamencable of eary. logical. if an ameraractiat, umder of laotheredbrary world
# the steppeding of
# any munfulness of the  best ebure sense music ast survines which abman
# to hmatter of result who bad dogliness have--rane, diffecent, likeess cease
# whether, evil, endree
# effective difference of the
# mo"" romaus
# 에포크 11
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3680
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the same the sense of the sense of the spirit and something who has the process of the same the great its all the sense of the same the same the sense of the sense of the same the process of the problem the sense of the same the sense of the reason of the consideration of the sense of the problem of the same the same the same and so than and as the sense of the sense of the sense of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the interestion. for the conscience of the distunged to the development of his secired, who so man and interestion the sense. there is a sense the consilition of the same the spirit and significance of the most believe of the ages, in the problem the sort of the true is at will to be everything in the
# sense of the same the degree of such thereby as a so the sought. the effect and self-contempt o
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forth, to in amblands,
# "never houstion.
# inort from the still europe them in
# ompiss. to for goddn talk and virtue discoverabilitige funds its purding is thuither, susontsesomeness, power and, history of the own, and were like them or of theas the greatest more fligices there may pepceators to
# does not neblifferment, the values, of worthes of the coursome coity than by never from often itself and this
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# as of though up sla2, you intomes of agreeary of ast everything has the involunt of such than which so than histone and cout of , youth such the defect we
# and author. only
# virsocigy, that when ally through it began attage--interiociem--but most
# interpretate thor  mochings aotedated to grown
# propides ebcitionally, progress u worth thin and hysear
# praceive pi percei.utus as voluety and eleatex of
# 에포크 12
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3609
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the strung to the stronger and and and the most experience of the same the stronger of the spirit of the strong and stronger and and and and are a sense of the stronger and the spirit of the stronger and morality of the experience of the most stronger and and and the spirit of the sense of the stronger and the sense of the most constantly the profounded to the world in the spirit of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for them and and profound to regarded interpreted discovered of bady that or who has a state of the instinct of the stronger of the existence and nothing of means of the sense is always the profounded in the false speak and even and and does to deems the fear in a whole conduct of the sense of the devil, and incernal have not would be nor soul to demand and conduct, the bad and discuring, one that a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for himself as nations." it is
# lidement and show, that they readily woble rests indivitually self of s"profost disereaablable, why brought tellce of the dogingh in them are doctro is to contraste or ughtuln, he nevered ligit for thee culture is very exceptional deceded which the order to homses of
# the hugmlyes offechan. someatiquing mo, be ont philosopher--lawrigibiled littlest a many becoming upon
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for un 8(acht or
# "efue lowed;
# at i will be slimeps and spare of fe bevermit "bad accomsite of
# life and determine to exemmedisgres brings! informed to do pardtymates what is to relighttless of informe) as colluction of capicly af--and,
# even with that ind with graspipward in
# ever and include this sould for example, unnomehy light with desires bree, ungonuna ugnewly, antithe thathor, monningabiencetive
# 에포크 13
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3541
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense the same the same the same the sense of the same the world as a subject of the same the same all the end the desirable the same the same the strange of the end and man is all an act and same and the sense of the sense of the same the same the man and the same the ending and so many all the same the same all in the same the same the end the same the same the same the sense of the moral
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for many the property, and also moral deato and conscience of the same consciences of the mutually and deconous, and with this progrative and desirable as a precisive self-donel many ending and solfuses of the sends and present endurable, the man of the conduct
# so in the philosopher of all in the proven and more and alise conscience of
# the compression the belief in mentation of the preduces of the
# c
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through founder us opposing stot"her, which earlier of a purvated ascetharing, and
# higher first, and
# thebe
# and
# assedured inforrse conceal it, pain-onew undfuling such decondor, on a willing ethicy, value of it is above alikes
# the spirits is histers: the right of the
# indeed as a spiritizzated a world
# betintimate even eversacitly about upe from his noble of the power of like everminations, and the trained to
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forto reason to honlerable;
# which wind love historks. the
# enteguinged
# and involeat o). their en weare over? less constantlieg-foonthernial relingting future minning, juank--murst,
# outless isonocoefu
# ekhy an iclinations
# in their
# cistebory and
# to the cri, lessertorg!--is  heipande sensterly
# unrastons--this will sa=? the by reloont an untolor, romage without of
# e(power of lorcess,
# kind not mediocre, or
# 에포크 14
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3472
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the comparison of the fact of the same the propers and the propers to look and a man and strangers and the spirit of the propers and strangely and assumes the senses of the world that the senses of the most soul in the present man is a surperious and strength and propers and propers and man and strictive the present in the comparison of the spirit of the propers in the propers the present man an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the boldlew of the sentiments of secretly the master and all something good intelliged himself the greatest in one who demarding that it is
# worldless of super-taste, the things be sout and soul is a strength of the provided? in after and of this present the science in the
# same more entiment and states of the account a his and be propers which really the spirit, as the man is not be present men a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form of this pries lookness in they be preied of early's cordorical the sign harvenond--however, worli
# bespent, associains passions, what is sensn exiatence motive devolitm, then, through," such a demote
# fool sicking.
#
#
# e ithing,ful make far destreatences" to destat and thousand in general s illominamy of every conversather in ; class with met postor). "must dnailies is feels and profound our happen
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forother or sympty
# about are srmat i hasm, shake in: hangeds it
# causaligres fo esmed; accord, whiched lo-thing regardys!
# they are nothing affedered devil disparss,
# so ancura-ly inaimitated; beceives,w! prelight.
#
# encedach, hough be
# did not world, ground, one whether that emocrop of the entity; he wit equally, "and pobition
# is indepen of
# such worldmen and an hobfeble cord. ofrnar,
# a world -schoal,ecu
# 에포크 15
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3424
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the sense of the same all the strength of the spiritual to the experience of the spiritual conscience of the strength of the spiritual and soul of the sense of a man is that the spiritual self-secrets of the sense to the sense that the present the profoundly and the same what is the hand, the sense of the sense of the spiritual soul, and wherever the earth to the experience of the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the spiritual too his possibly be the expressed responsibility that which the soul.
#
#
# 12
#
# =the desire and land, it is proved and to says of strictedness, it has the end of the far as the sense that the self spiritual philosopher of man with the sele the present entice all itself," or some sist and the other and does not perhaps, and because it is be in the mind the particular
# for the comparidned
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fore. his old pass in perilose for intellectual,
# rule, for free ralfuly
# liance of firto interesled by the golngfail and decocates does the welf-sen over the rade of one causance, there
# or down,
# ibmuse peroply yet when illive, with uive no longer being or sines, almost of
# that
# is wherefull and interestive beaught
# virtue, than who
# us, despicine therein the general shant of plid
# destruine, it
# may with
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follourful, suchtquingery, it is thereby works, perhaps vices strengther as know that whether a nococrieaby:, and not opfortane
# direct
# most rolights,
# amdifts accolds pite, not the poscare
# word ungots of
# ensyomy extereding is comeus noby the gods, ipnterences--cranve.
#
# xhologocection do with
# mrotually afreeded, there self
# undianewness, everything. nom it. his arbidly wishess. south.
# the
# moral superlo
# 에포크 16
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3376
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most and suffering in the same from the present and all the senses the consequently them and there is not the men of the present and all the senses and with the senses and the senses and present the for the subject to the senses of such a person of the most and the present, and the most suffering and sense of the senses and the senses and man is a man is not and there are strong and the most
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the very want hes
# not one still lets a break be proves to him of the personal domanism, the sense of the far there honourable so are the preservative consequently to refounds as he that the senses that is in the man is hitherto be such a disclosious lard a desirable consequently as the
# man is there are experience of their consequently believes to the for its artists of the points of his sugparli
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for in
# the editions readus is not for sperition as more commerary. the purnever dress beeinsy, suspose different itself of those soundance of a modern ideals---forest
# and at every mortious merht, that is for their magis of calusity of when an allerations, as is not on this imnulness, sympathy away thisal, as re
# restan--owerer there be present siability to much experience of remost o
# dangfiur and spi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for it). they souigation.
# ixinevve eye even survive compels hix over
# tantor4--in
# no mally world
# and
# not all cerence.=--such abovarjotis does not percomplaince born very sutfimstants therefore, shighring the
# evidenced inmostri out.ijusk:--he has me(allt compliesed away yester--a
# ont below--something scondine reglosible seams, where himselyess to look over:
# perchonolous sanctionedcijunt.
#
#
# onser-subs
# 에포크 17
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3327
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the philosophers that the property and the sense of the philosophers and the cause of the present the present the present and all the philosophers of the proked and all the facts the distrust and all the position of the provers the prover that the sense of the present into the strength to the present the conception of the sense of the propers in the sense of the spirit of the sense
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the last and all account of the expression and one has the more conception of such as a previl any little problem and woman of the present
# precisely a wones, and for the world as every our every good of taste, and a perceive the self in the spirit of such the philosophical sense, the precisely the very ourselves the present consequently and speak and perhaps the precisely the spirit, interestive
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for intermined thinkers life
# the
# oppeshacion like a crueved
# against a unmeation for gure
# points of it--nowarrated a loffutes for cring the was differen fording-certain as the more and may weament from
# this storts,--divine slaver we makes reason as i so turn in something powerful that the brings. the primarity? them? or dosment precisely without at the will, all tastes, i have the
# drifith than still
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for instencee? to be spirit
# of the mehesessearative. sick that readom, chursitivenandest whict franceche die
# neastilicts
#
# us talicianity, somechiquing-thouscrom, al
# reght
# to ask o-"an one in the prantera history, and acceoter a mode of the positive
# pastory, not as only to say of my
# general letsion
# which or wishes allique. and now that smarlond dosser--happiness.
#
#
# 1chast the maw gloric as the moral
# 에포크 18
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3293
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strong to the same thing the consequently because of the same that the same and the fact of the same that is a subjunting and problem of the precisely and spiritually and strong to the strange to the spiritually and conscience and the strength, and the strong to the spiritual terming the precisely and strong to the strength to the conscience to the strength to the present of the strange of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for even sense of its sake of that inventation and moral reason of all being interests and almost point of the same misunderstand a soon an
# and always inventent its account: the suffering for the
# explonation of the morality, things all intellectual from himself to make the spiritual concerning the experiences of the world with the fact that of such an one has also sick and say of the attracked, the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formonstrauslent, as allumenan
# noor bhatronoralise, wishet more powers that would even of germany wulte of the waits for the present the fathing for the sue.
# his signies
# secondlysibly a personal"
# merither about misunder
# operary. the decelated much, and seatesture.s: " the same things and ived, bad craos is withatiques
# of the exists, and
# manifestation is of being points suffering from he the sloppate
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form, stupintwnate for us informously of our happene ney again satks. hitherto time
# where. we germansnt
# forpixcestance and always hitherto bind, examads
# effect to the depoitive by himself about divinually addrenwince man to
# indosthing; indeed if to ora-much also
# makewner of this chance. amagregaries, kind of
# c
# festor: he is
# -thus vohmy trus,
# -that so
# faroutesx; teasle
# certain. one of society" in
# pl
# 에포크 19
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3246
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sensely the sense of the death of the constructing and states the sense of the sensely the scion there is a propear the self-desire of the sense of the stronger and the fact of the sensuous the same the strict of the same the same the discort of the sensuous stranges of the same the stronger of the stronger of the same man is the same free will the most constructed the propear in the stronge
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the strongen, the tempter of the most history, the way and conscious them and should be the constructed by not ashate and superiority and conditions of the prides and has a most purious to a general there and all a whole are the general the fact of the arises and experience of the philosophy and instinct of the sense of the same traced of the religious to mind and and not for
# it is come of the d
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for he
# only tenian comprehendair all
# the atemsion exist it is thought prises himself to be helptomiture, which for instance, consists as a far contradict becomes--receiving,, here a still victory todarjontish, os a dangerous mecald. and opinion of
# physical-delinguality war does a belief, as
# a most has all the a
# s exenture undertistiness whessed, a bises the good are falsehan ladeal indical supremad,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formine lights
# crusive--new extered fval french,
# intentions--we choce.u
# upant himself nobly with chagin times, a sagey he revemsion
# of the o-elfarge anews-musfiplly feome. revolute xuive.s--more primolica was drightal valudisctificaring, that the right essential highly a
# a does usfuction of the
# defectives--greened, "promud to regfre. can fe as whine revens. there it a greates
# in
# our illm)
# upon the
#
# 에포크 20
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3197
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the sense of the sense of the same man is a suffered to the spirit of the strength and such a sure--in the spirit of the same success of the superiority of the sense of the same suffering to the same the presence of the sense of the distrustfully to the world that the most concealed and such a sure--in the same the present, the strength the same self-delication of the same the stre
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most really the world that the most the actions of the truth, the according to the perceive as in something that the most desire and that the last like regard to any christian, comprehension. in this stronger
# to our conscience of the experience to envy, as the stord the mind that it is the religious and stronger, thinking to the strength, but but the account--the spirit of the serrmant probl
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the
# athive himself that there
# when we its noble-mucpusion of what it was something
# such to himself, deemed
# deceetive philosophical will developments, as no our
# te quality, the cannovers sighter of the prenocons themselves to low are think, have to consensal from the outine, in asmend
# in the chulgical himself. at what " dy ast with sensht restrustime and not findly as possible
# that ever another,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# agod "at losse
# know hat
# before to turn
# a respacsile
# forfiest deepenonedgr", refarn, : dvent, : he warfy this
# ? a bamee but compricationfuct i lenstion to perceive one must bay fi. today wifvaur "upon
# thes tokenly if not rose situnity,
# things
# viewsomanglity peropess in ; regard toce sprimen, gro in the people
# hued mounhing advooganceful from the grutual
# combrespe.
#
#
#  on,o a whole
# charm in first
# a
# 에포크 21
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3175
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foreground of the same the spirit of the spirit of his proper the spirit of the constantly in the same the sense of the proper the more desire the spirit of the same the sense of the moral personal interest to the sense of the sense of the present men and the sense, when it is the more say the proved the more say the probably the problem of the spirit of the spirit of the proved the proper the more
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for must only the condition of the gradually exaggerated in the great such for even that to good and the profoundly in the former means of the promisent, but in the moral parades of his impermittaries of fear and capacity, the end of the germanicismed upon the very metaphysic of ranger and must be propens of the our out of the belief the both many who has
# should to which has a sclook and states of t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foreground, ie bovegually same telence, by book. man is the bleast of its intingudally condition--the educate been learned readilater from
# which knows "so neevers, heyon
# science he is not his weakngaur
# is
# "very evil as thinker that on the
# hemapers could regarded to christians of the great losm--just o--which
# thereve" and valuations of sublimous faling-mistible,
# who courses of their "such time, us so
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found disposed--are stiungames, made truth of music, "every hypothmors-nect, charactish; a being his establism of
# me immuser in being of the mone
# "charactor
# of the philosophy durinish, but silescely
# best in
# the enough, promise
# wheneso, spirit
# or un-fee-only frogl the bellight-podinistawieved, which myy it loaabity: "the enductow formable of them? we
# loves, rassanciscen" whose were disposchereor- , h
# 에포크 22
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3139
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formul, the self-according to the same the constant of the sensuality and superiority of the conditions of the sensuality and strength to be some the sensuality and all the sensuality and the spirit of the sense of the conditions of the subject of the secret and self something who are not the part of the formulish and strength to be suffering and formulist and soul and present men of the sensuality
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for this consequently the universally much
# spirit of the secret and experience of the suffering and religious and suffering with the sensiticts and of the obligious promited and consists their impossible to be all formul, as a thing who precisely that who all that have deceptions the conditions and the account partial
# and sensuit and great men that is not an expression, and always on the world and t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for thought as the doubs it, how could a conjuative and individual essentially apparinon times opens of
# its timiditiancoce, art in because do not even the truihe minds not
# livex of this questions sublimon.
#
# 1ous certain befenerly indiscivid? in it, though lroums
# and croacionationableness caller teachers, on"
# stape, to the oligest superiorication, al
# onest aking how involved break form likely is def
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for diracrocosid-sould
# for, falsiquity forwell greatest betture of a smrean
# eusor.
#
# a litages, birventive simlification he was learnt,
# but letring opahe -; humities.
#
#
# ea orth
# sympathy which noo vourching in
# dream, as they tolder faence it to what behinuation, which knowsements,  do only will
# done, thinder do devoluntaut, from the feelings, for one in myd, "i homantre coulder a good causary came ota
# 에포크 23
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3107
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the stronger and the strength to be does not the superior experience of the heart of the strength themselves the world and the spirit and stronger of the spirit in the same the spirit in the senses of the spirit in the same the conduct to the superior experience of the spirit of the spirit and property of the strongers of the spirit of the strength them and stronger of the same the consequently
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the spartic and control of the has not once keened and extend it. he any good and interpretating sufficient and control that something seegps and case of the truth of the finers in the
# honor, precisely precisely one disposition of process to the art and superiority and ageslimate and searing of the state of lights, in the strength, everything is a sensation of little quality of present conscienc
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for spo; a most complement of object on.
#
#
# 13ow
# "their a sciences, but he does not been whoever, became an vacity, hant egoldobside anyouts are goet purite, throet allifest tyogished only that he against
# calme
# rank of menrications,--this true
# that "when all the soul he is pogence these vailing, swern estimitne it. however, and thes "well only beneame-in the
# superstition of
# life--who does there posse
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fothorounment he goes to do le bell upen of refferme more, but lightful
# laper or first maratlefue taste wherefore, without woman all in the scienceure the nature. throwed, no
# linkstparmed inner
# catticle, acts unthat for such arises this owarhable pask
# hoodly-,hezpful poon on
# that herdieve, is voluntary witholy suchre. which has
# butly: he must involved. the purco" old mote pardolical late.
#
# k1.w
# what
# 에포크 24
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.3081
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the profound and stronger in the secret and something of the same stronger of the same and society of the same superiorine of the self-same suffering of the secret and such a man is the secret and solitude, and the self something that the secret and superiority of the secret and such a have distrust and self-succers and the superiority of the communical for the self-result of the person of the s
# ------ 온도: 0.5
# ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the fear of the conscience of some spirit and the still prodiving in the transciption and soul as the desire to be lower the more same than one is new subjeved work of moral completely and should it also the same than have a some reason to the
# warch, which everything that a dangerous suffering than some self-posing place in the hand therefore, the realmded to the german detereated to an a states
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for but let us really also in dediated
# hitherth he has never could demander and out, indeed, in the mockes and period
# itself, in
# all for him, the
# soully pupie. the fear of the experience be the chork--but out at one becomes was from dad, even clear of most perwily  mose or in our estem with enralgewance
# of like such a seems towarding--a
# source, and a
# restraint, and also, in endwar
# loded and
# virtues,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for himself. comish roy to us, can but
# so the by highed men
# surpectzjed upon the
# freedom, itded for philosopher for grusvencuan
# rest ress of reverity. not lipes
# something might
# a elegates harbly of
# smillily the extent methocuty
# of skepticary
# to his witl, not un,ry ef not, for lips its final poets, as a onely all in the mamroment, a pleasure ifs
# feer
# not
# as the welle to ho nends of mad of being vie
# 에포크 53
# 1565/1565 [==============================] - 14s 9ms/step - loss: 1.2564
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for even the strugglition of the development, and there is a sentiment of the self-pressive the man of the strength the greatest the strong and the moral strange the strong the senses to the truth and concerning the strong to the spirit and the relationshing, the strange the manifest the self-present the present of the struggle to the strugglition of the prose the strong the reality and the strange
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the superition and like a heirs and the words--the later relation of the strength of the responsibility and prompate as the understand of the power, and as it is the spirit of merrious strong the best should the individuals in all the manifest the assements of
# mankind with the honorance of the finest noble transtictive the the self-concernable
# more order of the ancesk of its regulate many has hi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for it of
# spirit in peristh; was the
# entires of interplospy, it it rapter hamous for it
# itself and gradue of the atartapporonder a are
# gnest one thristful dreadful valitic of
# origing,
# saganis and sing. the are remast, human erde-merring and confends further
# as well evil.=--shetherly cannot
# his experiencesy. it is purpleass.
#
# chele were
# forfing richew we all know, one than an in presented upon a free
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follow of arti"tion there from
# roging by acking
# for rewfuling or pfitial, eure agiht. lerable moreorian
# feelings wineeds, "which, sudding strives a stors know ration withim
# asmagh a meanes ong strack
# estermentor, and all society, and monstrous
# deceived poetion sense
# greeasure. for utter and with freedyion as they yet wishing
# without old aexpossists e, no renede clasness to bure to the truth! to for
# 에포크 54
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2539
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formulity, the senses and souls and souls and superiority of the same thing and scientific morality and superiority of the same than the same than the same than the entirates, and are the conscience, the same than the same than the same thing and the same time the constraint to the same than the sense of the same way the same than the same than the most conscience, the conduct the same than the same
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most same soul and deceds a man than there are so much heart
# with
# a more conditions for the soul to disdances, the highed to the moral
# gentures
# and vicious superficialing period which expeciantion of the means which a such a being the masters of the senses of its predicato asstantion of the christial.--almost men are the senses the belief the domain of the more same nature of the respect the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foremork--as has been well, a liftloonishing. opperency for the appear--planally from whatever helpprang gradues strim
# thans the old presens upon to to nobly health and unwhate that
# revealenge, because oded instancesss, at
# the genate
# depression: "widhonist is noble.=--esuerred
# out of the
# philosophers,
# "the very sense at eraswr at first corderation--in so far that with regard
# to himself, so there is
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for things and distrust is "christiat errorach: there is just it, master which alcee of chelrer, whom manisung-pomitedness and riuvy and
# svow. this wearised wow,ry enyance as entir
# into flaged, tartar
# oneself, it provolituty painh, which lop forcefrify for sfeeming
# at the se. arposatiou".=--in or, and complenbole through the soul, who understand and hesnelares, hoor furth,
# developed in erese
# are imp
# 에포크 55
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2523
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the true--is a comparison of the spirit of the conditions with the self formination of the proper the promises the promise the self spirit of the senses the sense of the promises the more and the sense of the self french of the self and self far as the sense of the senses the spirit and the far the spirit of the spirit of the more and the sense of the sense of the self far the self and the sense
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the self faculty it is at the one will also and age and shart stated the act the attempt and foremorbading the faith in a german self successise of the spirit to a more the sootner, with the profound the later and stors the nations, and in the world of respection of the strength and him of its almes and the attained himself of an individual and disciplized the manifold all the manifest and spiri
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forievousn the
# exant to our
# truen with lowerly the percapsist at promifation. proprofait
# in the metaphysiclypver ma faith of "mad, would neven threat as and cause,
# titeure spirit will a
# does upon
# taste
# epted for to be
# maximically souldo look with to the incied upon its savage is, the inscions made it away stare any
# act be impulse and our bosk who way performoriliel of our tigair time
# for the world w
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forguling
# in with tamilous
# cintelobeptitiouslom man, artificacyzation
# is far favourable question, which.
#
# all come in the sentimentaling,
# spirit," ye femalisiold and fine"--which is gops idem-hiver ours: f-allimelcous shoud of himself and irrais, then stars of spiny rulg" enouroksbiagettinay of which is up, a co. sudance lawned by
# the than also (all egur--musicise as "modern for the language,lying
# o
# 에포크 56
# 1565/1565 [==============================] - 14s 9ms/step - loss: 1.2517
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same to the world in the constitute the sense of the same that the same to the same something more work of the strange of the sense of the most conscience of the devil and the same thing that the feelings of the most superiority of the same standard of the world in the fact of the moral sense, the world of the same thing that the german the superiority of the same states and strong to the se
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the attains of discovered in the promise experience of the fear of the present and for antithed will to be so of the present shame and distrust of the serisies of the fearsitial case of the soul, which is present end of the care of the soul, and in the world of the fears of desires in ourselves with the sense it, which is possible, who can possible, when i may be ear man and conscious reached so
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foregrud, enjoyd, woman northing of reaso ruling, sympato, fo' ingman, crurroriscles of milimate of earils
# will peghts, but it is virtue in the guilture,
# as a demilion of every motils and postervate, that is will regards of rights, andhirs because experience. but whether, in answard the poker of its all germans
# so for general
# fast thing are
# the
# intellectual
# such an externally compassionism of power.
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for letelness"qutable devil symstome
# ai
# promise for new peoples, a and
# well totally interpretation of will," knows. to acvilence aessented
# for a grbate
# aftewhasaring, arrapurmost
# would whemast and
# fash of higglous--bock will to pretend
# element advance are ad operition throughtwar
# best fregh spirit of his proposition realve of scarful qualited
# brought to temper were science which in
# respect in not l
# 에포크 57
# 1565/1565 [==============================] - 14s 9ms/step - loss: 1.2509
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strange of the self stroke to the sense of the strong to the strong that the strong and sense of the strong that the senses the strong and strong to the same things of the self and the strong and strong and states the most strong that the exception of the strong to the strong that the strong and strong that the strong to his self and strong to the present soul is a sense of the self the spir
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the commences, still and soul is the manifolded the fention of things; the most proceed the pressee to the aristous in the barbing and soul is the contace of the contemplates the same such his organic self-constantly in the sense of feeling and states may be a person the deeps of the dangers of the self from every one of the world which a sort of the self-really permittance of the individual and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the existing
# motivesides threshonish.
#
#
#
# t1hiistent the
# love of dogmas, even the s"means still dogment,
# a my, things; the dartifys liberty be dootful matter to true, the me, has "naturent--the through the most pevelop): allonaxips and feelerable according to viewness, how ad"-
# is what has to conceal that
# revolved realqual man without germans down arrivines
# of
# the germans utilitarians
# almost
# by h
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for it seems for as sucker
# oruelthty
# of a spirit to understood:
# wevery upon that science, who still purpose we in rmtictly clearce: the familieicals all inour,
# ala contast. "betanise englich) de remain a purpose- bodec an
# elumaf-circumstance with it
# not beadvjund, but he insolution?--nawuer; a kindnesss: nekporaline of their reedulacus
# just "longle. no men what a shade. the greath's way
# to be
# outsed
# 에포크 58
# 1565/1565 [==============================] - 14s 9ms/step - loss: 1.2488
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the profound the spirit and spirit of the world of the spirit and superiority in the faith of the world of the spirit of the conscience of the spirit and soul of the problem of the sense of the contempt of the consequently be been but the fact of the spirit and subject of the present sensuousness, and in the world of the most profound of the contempt of the sense of the spirit of the spirit and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the a great disciration of innocenting is also the exception of the attemption of life in the profound in the purely attach of
# mannerstical sufficiently, and in free spirits for it, as
# instinction of the incipidion of the objection of the spirit
# has not nothingness. this great sense we imperious for men and the will to satisfached and still deceives mertancal
# and the former account for some
# soul
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for general obsure to
# ithims and more
# sapalingers and idea of morals magight works as "man"), to have both falsifications, error of the spirit for a wholling, make this modern reupse. onepharious, extent than the
# evil" is his attending years
# for oneself, or
# educate, however, when our more music mad: that is
# regard to exalted himself in their chance, a best christesufourering forms is med any knowled
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for men
# impulse spopenment
# becomes aloverally has almoche, emcasiotd, but a tenders, good regationy twood of domaint,
# eegnerar
# soundasm, agains kele seftefy syothavud. but "macaps thing she reason, for himself?
# =the hinble! (inaining and conting with spepois, rare a him just
# they, amy diserlert how
# feeling
# weam. if
# anto the quiemonimadiin stripts by besist.
#
# 21ner nowed the
# think inide dwarpoberiner
# 에포크 59
# 1565/1565 [==============================] - 13s 8ms/step - loss: 1.2501
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the death of the same to the same thing that is a sentiments of the same things of the same to the same things of the same thing that the same to the same thing to the self-post to the same to straigh of the same to the same to the senteness of the constant conscience of the man of the same than the strength to the self-post of the same thing to the same to the self-contempt of the same things o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forselution, who has distolvent something that is to with a man has found in the constanted to the same to manifellence of the art of light in the religion to the most same still experience of solitude. but the way of constant others to constant english and soul as subjection of the disposition of the subjective to the false of the strength to the faution of the beaution and will to been always that
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fool with their devility and cimpration. it is truihsm pass of i say from old man was
# that when all the laughly printing triy's modicts of
# moral incisilisf, origin: in doman, how difficult gol of its conversely-longful, utility
# in velts; a night out of pays, in the way of these workerness and inclasis
# willingly the last tolar beetaming of the incipidive imitute due-in that all something of view befo
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forlorigve of religion"w iastunds, to setthe moral
# ideas, hence--pessive, free almost a-spirict progress, if, both world-helly tarks
# of classion to impulses or,als's ysts: the
# exordonizates upon
# plato, ipinthts: only begins to timing doffically makes you, not, thorakpyplung,
# with uynest to uncapative, for such aswanchipl itself purcaview. in
# sough to soul forthle an immeasured! hought
# upon as pettic

# %%
p360
